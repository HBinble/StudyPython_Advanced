# %%
# bicycle.dup.csv 파일 읽어들인 후 조회하기

import pandas as pd

# %%
file_path = "./data/bicycle_dup.csv"
df = pd.read_csv(file_path, encoding="euc-kr")
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자전거번호    420 non-null    object
#  1   대여일시     420 non-null    object
#  2   대여소번호    420 non-null    int64
#  3   대여소명     420 non-null    object
#  4   대여거치대    396 non-null    float64
#  5   반납일시     420 non-null    object
#  6   반납대여소번호  420 non-null    int64
#  7   반납대여소명   420 non-null    object
#  8   반납거치대    409 non-null    float64
#  9   이용시간     405 non-null    float64
#  10  이용거리     404 non-null    float64
#  11  나이       420 non-null    int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 39.5+ KB

# %%
df.describe()
# Out:
#              대여소번호       대여거치대     반납대여소번호       반납거치대        이용시간  \
# count   420.000000  396.000000  420.000000  409.000000  405.000000
# mean    243.254762    7.585859   93.338095    2.843521   21.185185
# std     301.148255    6.258985   26.270667    1.699182   20.200058
# min       3.000000    1.000000    3.000000    1.000000    2.000000
# 25%     104.000000    3.000000  101.000000    1.000000    7.000000
# 50%     117.500000    6.000000  101.000000    2.000000   14.000000
# 75%     226.500000   10.000000  101.000000    4.000000   27.000000
# max    3102.000000   30.000000  101.000000    7.000000  122.000000
#
#                이용거리          나이
# count    404.000000  420.000000
# mean    2683.465347   35.492857
# std     3025.803402   31.829010
# min        0.000000   21.000000
# 25%     1070.000000   24.000000
# 50%     1680.000000   29.000000
# 75%     3757.500000   40.000000
# max    42070.000000  533.000000

# %%
# df_temp 데이터를 이용해서 결측치 및 이상치 데이터 처리 연습하기
# df는 사용하지 않습니다.
# 결측치와 이상치 처리 방법은 자유롭게

df_temp = df.copy()
df_temp
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df_temp_allow = df_temp.dropna(axis=0)
df_temp_allow
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 5    SPB-18401   2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6    SPB-18350   2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# ..         ...               ...    ...                ...    ...
# 414  SPB-24515   2019-11-15 3:58    112            극동방송국 앞    1.0
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df_temp_allow = df_temp_allow.reset_index(drop=True)
df_temp_allow
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 3    SPB-18401   2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-18350   2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# ..         ...               ...    ...                ...    ...
# 353  SPB-24515   2019-11-15 3:58    112            극동방송국 앞    1.0
# 354  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 355  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 356  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 357  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df_temp_allow.describe()
# Out:
#              대여소번호       대여거치대     반납대여소번호       반납거치대        이용시간  \
# count   358.000000  358.000000  358.000000  358.000000  358.000000
# mean    239.907821    7.578212   95.011173    2.810056   20.860335
# std     310.908545    6.185125   23.438336    1.682904   19.997550
# min       3.000000    1.000000    3.000000    1.000000    2.000000
# 25%     104.000000    3.000000  101.000000    1.000000    7.000000
# 50%     115.000000    6.000000  101.000000    2.000000   13.000000
# 75%     225.500000   10.000000  101.000000    4.000000   27.000000
# max    3102.000000   30.000000  101.000000    7.000000  122.000000
#
#                이용거리          나이
# count    358.000000  358.000000
# mean    2707.458101   35.226257
# std     3138.218904   32.753843
# min        0.000000   21.000000
# 25%     1070.000000   24.000000
# 50%     1680.000000   29.000000
# 75%     3802.500000   39.750000
# max    42070.000000  533.000000

# %%
df_temp_allow[df_temp_allow["나이"]  >= 100]
# Out:
#         자전거번호              대여일시  대여소번호         대여소명  대여거치대              반납일시  \
# 2   SPB-07935  2019-11-05 12:29    512  뚝섬역 1번 출구 옆   11.0  2019-11-05 12:39
# 19  SPB-20840   2019-11-28 8:32    419       홈플러스 앞    1.0   2019-11-28 8:35
# 33  SPB-11637  2019-11-01 15:35    103   망원역 2번출구 앞    4.0  2019-11-01 15:41
#
#     반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 2         3         중랑센터    7.0  10.0  1650.0  120
# 19        5     상암센터 정비실    5.0   3.0   280.0  533
# 33      101  (구)합정동 주민센터    2.0   5.0  1110.0  320

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.boxplot(df_temp_allow["나이"])
plt.show()

# %%
df_temp_allow["나이"].describe()
# Out:
# count    358.000000
# mean      35.226257
# std       32.753843
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       39.750000
# max      533.000000
# Name: 나이, dtype: float64

# %%
import numpy as np

# %%
q1, q3 = np.percentile(df_temp_allow["나이"], [25,75])
print(q1)
print(q3)
# Out:
# 24.0
# 39.75

# %%
iqr = q3 - q1
iqr
# Out:
# 15.75

# %%
upper_bound = q3 + (iqr * 1.5)
upper_bound
# Out:
# 63.375

# %%
lower_bound = q1 - (iqr * 1.5)
lower_bound
# Out:
# 0.375

# %%
condition = (df_temp_allow["나이"] > upper_bound) | (df_temp_allow["나이"] < lower_bound)
print(len(df_temp_allow[condition]))
df_temp_allow[condition]
# Out:
# 8
#          자전거번호              대여일시  대여소번호          대여소명  대여거치대  \
# 2    SPB-07935  2019-11-05 12:29    512   뚝섬역 1번 출구 옆   11.0
# 19   SPB-20840   2019-11-28 8:32    419        홈플러스 앞    1.0
# 33   SPB-11637  2019-11-01 15:35    103    망원역 2번출구 앞    4.0
# 117  SPB-24758  2019-11-04 17:59    106    합정역 7번출구 앞    7.0
# 180  SPB-06127  2019-11-06 16:06   1925  동양미래대학교 정문 옆    6.0
# 246  SPB-08818  2019-11-08 23:13    108       서교동 사거리    2.0
# 305  SPB-24781  2019-11-12 10:45    101   (구)합정동 주민센터    3.0
# 306  SPB-24858  2019-11-12 11:41    113  홍대입구역 2번출구 앞   21.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간     이용거리   나이
# 2    2019-11-05 12:39        3         중랑센터    7.0  10.0   1650.0  120
# 19    2019-11-28 8:35        5     상암센터 정비실    5.0   3.0    280.0  533
# 33   2019-11-01 15:41      101  (구)합정동 주민센터    2.0   5.0   1110.0  320
# 117  2019-11-04 18:20      101  (구)합정동 주민센터    5.0  20.0   1130.0   65
# ...

# %%
import numpy as np

def outliers_iqr(dframe, data) :
    # q1(25%), q3(75%) 데이터 확인하기
    q1, q3 = np.percentile(data, [25, 75])
    iqr = q3 - q1
    upper_bound = q3 + (iqr * 1.5)
    lower_bound = q1 - (iqr * 1.5)

    condition = ((data > upper_bound) | \
                        (data < lower_bound))

    print(upper_bound)
    print(lower_bound)
    print(len(dframe[condition]))
    return dframe[condition]

# %%
temp = outliers_iqr(df_temp_allow, df_temp_allow["나이"])
temp
# Out:
# 63.375
# 0.375
# 8
#          자전거번호              대여일시  대여소번호          대여소명  대여거치대  \
# 2    SPB-07935  2019-11-05 12:29    512   뚝섬역 1번 출구 옆   11.0
# 19   SPB-20840   2019-11-28 8:32    419        홈플러스 앞    1.0
# 33   SPB-11637  2019-11-01 15:35    103    망원역 2번출구 앞    4.0
# 117  SPB-24758  2019-11-04 17:59    106    합정역 7번출구 앞    7.0
# 180  SPB-06127  2019-11-06 16:06   1925  동양미래대학교 정문 옆    6.0
# 246  SPB-08818  2019-11-08 23:13    108       서교동 사거리    2.0
# 305  SPB-24781  2019-11-12 10:45    101   (구)합정동 주민센터    3.0
# 306  SPB-24858  2019-11-12 11:41    113  홍대입구역 2번출구 앞   21.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간     이용거리   나이
# 2    2019-11-05 12:39        3         중랑센터    7.0  10.0   1650.0  120
# 19    2019-11-28 8:35        5     상암센터 정비실    5.0   3.0    280.0  533
# 33   2019-11-01 15:41      101  (구)합정동 주민센터    2.0   5.0   1110.0  320
# 117  2019-11-04 18:20      101  (구)합정동 주민센터    5.0  20.0   1130.0   65
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

if platform.system() == "Windows" :
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc("font", family=font_name)
elif platform.system() == "Darwin" :
    rc("font", family="AppleGothic")
else :
    print("Check your Os System...")

# %%
df_temp.plot()
# Out:
# <AxesSubplot:>

# %%
# 전체 중복체크
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %%
# 컬럼단위 중복체크
df.duplicated(["이용거리"])
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417     True
# 418     True
# 419    False
# Length: 420, dtype: bool

# %%
df["이용거리"].duplicated()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417     True
# 418     True
# 419    False
# Name: 이용거리, Length: 420, dtype: bool

# %%
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df.duplicated(["이용거리", "나이"])
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %%
df[["이용거리","나이"]].duplicated()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %%
len(df[df[["이용거리","나이"]].duplicated()])
# df[["이용거리","나이"]].duplicated().value_counts()
# df[["이용거리","나이"]].duplicated().sum()
# Out:
# 15

# %%
df[df[["이용거리","나이"]].duplicated()]
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 11   SPB-20145   2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 17   SPB-02270   2019-11-18 8:49    646  장한평역 1번출구 (국민은행앞)    4.0
# 20   SPB-21925   2019-11-22 8:49    529       장한평역 8번 출구 앞    5.0
# 210  SPB-19171   2019-11-06 1:42    151           망원1동주민센터    NaN
# 229  SPB-06190  2019-11-06 18:23    226         샛강역 1번출구 앞   12.0
# 236  SPB-16119   2019-11-07 2:27    151           망원1동주민센터    6.0
# 238  SPB-06454   2019-11-07 9:07    103         망원역 2번출구 앞    4.0
# 267  SPB-16032  2019-11-08 13:06    152         마포구민체육센터 앞   30.0
# 268  SPB-22576  2019-11-08 14:01    421             마포구청 앞    1.0
# 295  SPB-16380   2019-11-09 0:35    419             홈플러스 앞   20.0
# 372  SPB-06102  2019-11-12 18:55    151           망원1동주민센터    9.0
# 381  SPB-06351  2019-11-12 23:47    103         망원역 2번출구 앞    9.0
# ...

# %%
df.loc[df.duplicated(["이용거리", "나이"])]

# 인덱스 값(loc) = 1, 11
# 인덱스 번호(iloc) = 0, 1 ...(보이지 않음)

# loc를 쓰는 이유(iloc는 boolean indexing 값을 조회할 때 사용) = 필터링을 한 결과를 조회하기 때문
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 11   SPB-20145   2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 17   SPB-02270   2019-11-18 8:49    646  장한평역 1번출구 (국민은행앞)    4.0
# 20   SPB-21925   2019-11-22 8:49    529       장한평역 8번 출구 앞    5.0
# 210  SPB-19171   2019-11-06 1:42    151           망원1동주민센터    NaN
# 229  SPB-06190  2019-11-06 18:23    226         샛강역 1번출구 앞   12.0
# 236  SPB-16119   2019-11-07 2:27    151           망원1동주민센터    6.0
# 238  SPB-06454   2019-11-07 9:07    103         망원역 2번출구 앞    4.0
# 267  SPB-16032  2019-11-08 13:06    152         마포구민체육센터 앞   30.0
# 268  SPB-22576  2019-11-08 14:01    421             마포구청 앞    1.0
# 295  SPB-16380   2019-11-09 0:35    419             홈플러스 앞   20.0
# 372  SPB-06102  2019-11-12 18:55    151           망원1동주민센터    9.0
# 381  SPB-06351  2019-11-12 23:47    103         망원역 2번출구 앞    9.0
# ...

# %%
# duplocated의 속성(defalut = "first")
df.duplicated(["이용거리"],keep="first")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417     True
# 418     True
# 419    False
# Length: 420, dtype: bool

# %%
df.duplicated(["이용거리"],keep="last")
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %%
df.duplicated(["이용거리"],keep=False)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 415    False
# 416     True
# 417     True
# 418     True
# 419    False
# Length: 420, dtype: bool

# %%
df.drop_duplicates(["이용거리"], keep="first")
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 5    SPB-18401   2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# ..         ...               ...    ...                ...    ...
# 410  SPB-18614  2019-11-14 23:07    391              정동길입구    5.0
# 413  SPB-25161   2019-11-15 3:13    106         합정역 7번출구 앞    6.0
# 414  SPB-24515   2019-11-15 3:58    112            극동방송국 앞    1.0
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0   50
# ...

# %%
df.drop_duplicates(["이용거리"], keep="last")
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 11   SPB-20145   2019-11-13 8:30    646  장한평역 1번출구 (국민은행앞)    9.0
# 15   SPB-13973   2019-11-15 8:42    646  장한평역 1번출구 (국민은행앞)    1.0
# 20   SPB-21925   2019-11-22 8:49    529       장한평역 8번 출구 앞    5.0
# 22   SPB-05857   2019-11-26 8:40    646  장한평역 1번출구 (국민은행앞)    6.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리   나이
# 4    2019-11-05 12:39        3         중랑센터    7.0  10.0  1650.0  120
# ...

# %%
df_dup = df.drop_duplicates(["이용거리"], keep=False)

# %%
# 중복 처리 잘 됐는지 한번 더 확인
df_dup[df_dup.duplicated(["이용거리"], keep=False)]
# Out:
# Empty DataFrame
# Columns: [자전거번호, 대여일시, 대여소번호, 대여소명, 대여거치대, 반납일시, 반납대여소번호, 반납대여소명, 반납거치대, 이용시간, 이용거리, 나이]
# Index: []
