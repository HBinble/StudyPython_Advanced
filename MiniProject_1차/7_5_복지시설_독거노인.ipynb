# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
file_path = "./data/./복지시설/경기도_독거노인_현황_연령별(2013~2020).csv"
df = pd.read_csv(file_path)
df
# Out:
#     시군별(1)  시군별(2)    2013  2013.1  2013.2         2013.3         2013.4  \
# 0   시군별(1)  시군별(2)      합계      합계      합계  국민기초생활보장 수급권자  국민기초생활보장 수급권자
# 1   시군별(1)  시군별(2)       계  65~79세  80세 이상              계         65~79세
# 2       합계      소계  320595  243840   76755          47421          32856
# 3       남부      소계  221134  166033   55101          30745          21435
# 4       남부     수원시   24096   19410    4686           4494           3234
# 5       남부     성남시   25061   18430    6631           3349           2383
# 6       남부     안양시   14299   10848    3451           1751           1208
# 7       남부     부천시   20403   15264    5139           2947           2210
# 8       남부     광명시    7048    5360    1688           1151            810
# 9       남부     평택시   12519    9362    3157           1872           1410
# 10      남부     안산시   15359   11774    3585           3197           2250
# 11      남부     과천시    1331     929     402            187            135
# ...

# %%
df2 = df[["시군별(2)","2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]]
df2
# Out:
#     시군별(2)    2013    2014    2015    2016    2017    2018    2019    2020
# 0   시군별(2)      합계      합계      합계      합계      합계      합계      합계      합계
# 1   시군별(2)       계       계       계       계       계       계       계       계
# 2       소계  320595  282210  301509  317698  338205  378779  435458  446375
# 3       소계  221134  190718  205432  218146  234953  263527  307134  311095
# 4      수원시   24096   20613   23212   24578   26711   34656   35993   40959
# 5      성남시   25061   24031   25222   26370   27527   29045   30962   33115
# 6      안양시   14299   12570   12823   12942   13445   14204   17552   19150
# 7      부천시   20403   18282   18282   19606   21143   22791   24665   26742
# 8      광명시    7048    7724    8085    8489    8957    9263   12911    9604
# 9      평택시   12519   13001   14394   14367   14695   15716   16199   19216
# 10     안산시   15359   14619   14292   15018   16538   17146   18261   19853
# ...

# %%
df3 = df2.drop(range(0,4,1)).reset_index(drop=True)
df3
# Out:
#    시군별(2)   2013   2014   2015   2016    2017    2018    2019    2020
# 0     수원시  24096  20613  23212  24578   26711   34656   35993   40959
# 1     성남시  25061  24031  25222  26370   27527   29045   30962   33115
# 2     안양시  14299  12570  12823  12942   13445   14204   17552   19150
# 3     부천시  20403  18282  18282  19606   21143   22791   24665   26742
# 4     광명시   7048   7724   8085   8489    8957    9263   12911    9604
# 5     평택시  12519  13001  14394  14367   14695   15716   16199   19216
# 6     안산시  15359  14619  14292  15018   16538   17146   18261   19853
# 7     과천시   1331   1690   1752   1672    1484    1511    1547    2253
# 8     오산시   3431   3304   3199   3396    4112    4323    4829    5724
# 9     시흥시   6571   2560   7150   7579    8051   11022   10407   11850
# 10    군포시   6483   6960   5866   6413    6201    7366    8384    8687
# 11    의왕시   3138   3809    309   3553    3668    3761   22445    3146
# ...

# %%
df3 = df3.replace({"-" : 0})

# %%
df3[["2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]] = \
    df3[["2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].astype(int)

# %%
df4 = df3.drop(21)
df4
# Out:
#    시군별(2)   2013   2014   2015   2016   2017   2018   2019   2020
# 0     수원시  24096  20613  23212  24578  26711  34656  35993  40959
# 1     성남시  25061  24031  25222  26370  27527  29045  30962  33115
# 2     안양시  14299  12570  12823  12942  13445  14204  17552  19150
# 3     부천시  20403  18282  18282  19606  21143  22791  24665  26742
# 4     광명시   7048   7724   8085   8489   8957   9263  12911   9604
# 5     평택시  12519  13001  14394  14367  14695  15716  16199  19216
# 6     안산시  15359  14619  14292  15018  16538  17146  18261  19853
# 7     과천시   1331   1690   1752   1672   1484   1511   1547   2253
# 8     오산시   3431   3304   3199   3396   4112   4323   4829   5724
# 9     시흥시   6571   2560   7150   7579   8051  11022  10407  11850
# 10    군포시   6483   6960   5866   6413   6201   7366   8384   8687
# 11    의왕시   3138   3809    309   3553   3668   3761  22445   3146
# 12    하남시   3576   4673   4305   4973   5378   8719   9815   8477
# ...

# %%
df5 = df4.rename(columns={"시군별(2)": "경기도시"})

# %%
df6 = df5.reset_index(drop=True)

# %%
df6_top10 = df6.sort_values("2020", ascending=False).head(10)
df6_top10
# Out:
#     경기도시   2013   2014   2015   2016   2017   2018   2019   2020
# 0    수원시  24096  20613  23212  24578  26711  34656  35993  40959
# 23   고양시  31456  23882  24031  26259  27135  29219  31815  34317
# 1    성남시  25061  24031  25222  26370  27527  29045  30962  33115
# 13   용인시  15646  16404  21176  18995  20541  21967  23976  26889
# 3    부천시  20403  18282  18282  19606  21143  22791  24665  26742
# 25  남양주시  16624  14882  16400  16595  18160  20009  21938  23907
# 6    안산시  15359  14619  14292  15018  16538  17146  18261  19853
# 5    평택시  12519  13001  14394  14367  14695  15716  16199  19216
# 2    안양시  14299  12570  12823  12942  13445  14204  17552  19150
# 21  의정부시  14221  12616  12627  13313  13902  15078  16708  18342

# %%
df6_top10 = df6_top10.set_index("경기도시")

# %%
df6_top10_181920 = df6_top10[["2018", "2019", "2020"]]

# %%
df6_pivot = df6_top10.pivot_table(values="2020", index="경기도시")

# %%
df6_pivot = df6_pivot.sort_values("2020",ascending=False)

# %%
plt.rcParams['figure.figsize'] = (30,15)
plt.rcParams['lines.linewidth'] = 2
plt.rc("font", family = "Malgun Gothic", size=10)
df6_pivot.plot(kind="bar")

plt.title("경기도_독거노인 현황", fontsize=20)
plt.xlabel("독거노인수", fontsize=20)
a = range(-1,32,1)

plt.xticks(fontsize = 20, rotation=0)
plt.yticks(fontsize = 20)

plt.legend(loc="upper right", fontsize=20)
plt.grid(True)

plt.show()

# %%
plt.rcParams['figure.figsize'] = (30,15)
plt.rcParams['lines.linewidth'] = 2
plt.rc("font", family = "Malgun Gothic", size=10)
df6_top10_181920.plot(kind="bar",stacked=True)

plt.title("경기도_의료기관 현황", fontsize=20)
plt.xlabel("의료기관수", fontsize=20)
a = range(-1,32,1)

plt.xticks(fontsize = 20, rotation=0)
plt.yticks(fontsize = 20)

plt.legend(loc="upper right", fontsize=20)
plt.grid(True, alpha=0.3)

plt.show()
