# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
file_path = "./data/./복지시설/경기도_어린이집 2010~2020.csv"
df = pd.read_csv(file_path)
df
# Out:
#     시군별(1)  시군별(2)       2010     2010.1     2010.2     2010.3     2010.4  \
# 0   시군별(1)  시군별(2)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)
# 1   시군별(1)  시군별(2)         합계        국공립     사회복지법인         민간         민간
# 2   시군별(1)  시군별(2)         소계         소계         소계         소계         개인
# 3       합계      소계      11273        464         73       3771       3641
# 4       남부      소계       7822        335         55       2743       2645
# 5       남부     수원시       1001         21          4        351        343
# 6       남부     성남시        646         43          1        222        215
# 7       남부     안양시        488         25          1        152        150
# 8       남부     부천시        602         27          4        290        275
# 9       남부     광명시        306         18          2         84         81
# 10      남부     평택시        359         16          2        163        158
# 11      남부     안산시        728         20          -        262        257
# ...

# %%
df2 = df[["시군별(2)", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]]
df2
# Out:
#     시군별(2)       2010       2011       2012       2013       2014       2015  \
# 0   시군별(2)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)  어린이집수 (개)
# 1   시군별(2)         합계         합계         합계         합계         합계         합계
# 2   시군별(2)         소계         소계         소계         소계         소계         소계
# 3       소계      11273      11825      12870      13364      13259      12689
# 4       소계       7822       8238       9092       9524       9501       9148
# 5      수원시       1001       1072       1254       1284       1311       1266
# 6      성남시        646        659        716        777        761        729
# 7      안양시        488        509        560        603        588        540
# 8      부천시        602        602        616        628        635        617
# 9      광명시        306        347        387        397        390        365
# 10     평택시        359        377        406        425        431        427
# ...

# %%
df3 = df2.drop(range(0,5,1)).reset_index(drop=True)
df3
# Out:
#    시군별(2)  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0     수원시  1001  1072  1254  1284  1311  1266  1187  1153  1135  1062   982
# 1     성남시   646   659   716   777   761   729   719   692   657   610   580
# 2     안양시   488   509   560   603   588   540   516   494   472   446   421
# 3     부천시   602   602   616   628   635   617   604   597   605   579   559
# 4     광명시   306   347   387   397   390   365   342   327   309   274   244
# 5     평택시   359   377   406   425   431   427   419   420   413   422   419
# 6     안산시   728   733   748   752   739   680   623   575   526   490   464
# 7     과천시    53    53    54    52    52    50    50    47    48    46    46
# 8     오산시   202   230   256   264   266   257   253   256   261   262   252
# 9     시흥시   428   429   427   433   428   421   402   420   440   465   484
# 10    군포시   241   263   322   320   315   297   274   273   273   257   225
# ...

# %%
df3 = df3.replace({"-" : 0})

# %%
df3[["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]] = \
    df3[["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].astype(int)

# %%
df3.loc[34] = df3.iloc[19] + df3.iloc[20]
df3
# Out:
#     시군별(2)  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0      수원시  1001  1072  1254  1284  1311  1266  1187  1153  1135  1062   982
# 1      성남시   646   659   716   777   761   729   719   692   657   610   580
# 2      안양시   488   509   560   603   588   540   516   494   472   446   421
# 3      부천시   602   602   616   628   635   617   604   597   605   579   559
# 4      광명시   306   347   387   397   390   365   342   327   309   274   244
# 5      평택시   359   377   406   425   431   427   419   420   413   422   419
# 6      안산시   728   733   748   752   739   680   623   575   526   490   464
# 7      과천시    53    53    54    52    52    50    50    47    48    46    46
# 8      오산시   202   230   256   264   266   257   253   256   261   262   252
# 9      시흥시   428   429   427   433   428   421   402   420   440   465   484
# 10     군포시   241   263   322   320   315   297   274   273   273   257   225
# ...

# %%
df4 = df3.drop([19,20,22,29])

# %%
df4 = df4.replace({"여주군여주시" : "여주시"})

# %%
df5 = df4.rename(columns={"시군별(2)": "경기도시"})

# %%
df6 = df5.reset_index(drop=True)

# %%
df6_top10 = df6.sort_values("2020", ascending=False).head(10)
df6_top10
# Out:
#     경기도시  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0    수원시  1001  1072  1254  1284  1311  1266  1187  1153  1135  1062   982
# 17   화성시   579   615   661   724   713   748   759   792   834   896   866
# 13   용인시   961  1001  1091  1166  1161  1099  1038   994   965   916   860
# 22   고양시   985  1035  1134  1182  1114  1002   917   855   817   769   717
# 24  남양주시   622   649   677   699   718   710   683   656   658   619   620
# 1    성남시   646   659   716   777   761   729   719   692   657   610   580
# 3    부천시   602   602   616   628   635   617   604   597   605   579   559
# 9    시흥시   428   429   427   433   428   421   402   420   440   465   484
# 6    안산시   728   733   748   752   739   680   623   575   526   490   464
# 16   김포시   195   231   330   373   411   408   394   407   447   444   440

# %%
df6_top10 = df6_top10.set_index("경기도시")

# %%
df6_top10_181920 = df6_top10[["2018", "2019", "2020"]]

# %%
df6_pivot = df6_top10.pivot_table(values="2020", index="경기도시")

# %%
plt.rcParams['figure.figsize'] = (30,15)
plt.rcParams['lines.linewidth'] = 2
plt.rc("font", family = "Malgun Gothic", size=10)
df6_pivot.plot(kind="bar")

plt.title("경기도_어린이집 현황", fontsize=20)
plt.xlabel("어린이집수", fontsize=20)
a = range(-1,32,1)

plt.xticks(fontsize = 20, rotation=0)
plt.yticks(fontsize = 20)

plt.legend(loc="upper right", fontsize=20)
plt.grid(True)

plt.show()

# %%
plt.rcParams['figure.figsize'] = (30,15)
plt.rcParams['lines.linewidth'] = 2
plt.rc("font", family = "Malgun Gothic", size=10)
df6_top10_181920.plot(kind="bar",stacked=True)

plt.title("경기도_어린이집 현황", fontsize=20)
plt.xlabel("어린이집수", fontsize=20)
a = range(-1,32,1)

plt.xticks(fontsize = 20, rotation=0)
plt.yticks(fontsize = 20)

plt.legend(loc="upper right", fontsize=20)
plt.grid(True, alpha=0.3)

plt.show()
