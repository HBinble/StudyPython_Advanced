# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

if platform.system() == "Windows" :
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc("font", family=font_name)
elif platform.system() == "Darwin" :
    rc("font", family="AppleGothic")
else :
    print("Check your Os System...")

# %%
file_path = "./data/서울_경기_시군구별_이동자수.csv"
df = pd.read_csv(file_path, encoding="EUC_KR", skipfooter=13)
df
# Out:
# C:\Users\Hanbin\AppData\Local\Temp\ipykernel_10592\2006991432.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, encoding="EUC_KR", skipfooter=13)
#     행정구역(시군구)별     2010     2011     2012     2013     2014     2015     2016  \
# 0   행정구역(시군구)별  총전입 (명)  총전입 (명)  총전입 (명)  총전입 (명)  총전입 (명)  총전입 (명)  총전입 (명)
# 1          경기도  2168820  2062422  1944962  1895434  1891775  1993080  1958593
# 2          수원시   184402   202035   200113   195500   196453   189637   172210
# 3          성남시   182500   171589   155354   162734   150240   152980   174390
# 4         의정부시    65756    65206    61489    65548    63021    66820    65844
# 5          안양시    99331    91534    96964    83335    81727    85267    96112
# 6          부천시   136267   140599   124199   119427   117954   123425   125460
# ...

# %%
df1 = df.copy()
df_gygi = df1.drop([0,1]).reset_index(drop=True)
df_gygi
# Out:
#    행정구역(시군구)별    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0         수원시  184402  202035  200113  195500  196453  189637  172210  177059
# 1         성남시  182500  171589  155354  162734  150240  152980  174390  157557
# 2        의정부시   65756   65206   61489   65548   63021   66820   65844   66965
# 3         안양시   99331   91534   96964   83335   81727   85267   96112   84779
# 4         부천시  136267  140599  124199  119427  117954  123425  125460  114426
# 5         광명시   87001   68937   52314   47076   46176   44735   41712   43201
# 6         평택시   67915   73419   72433   72028   68508   77256   75179   76783
# 7        동두천시   20437   17225   17907   15920   16052   16300   16074   13422
# 8         안산시  121052  119858  105760  101514   98715  103260   93537   78735
# 9         고양시  174090  173745  157485  171535  166111  176821  158904  139002
# 10        과천시   12035   11230   10328   10181    9925   10037   10957    8304
# ...

# %%
df_gygi.loc[27, "2010":"2012"] = 0
df_gygi
# Out:
#    행정구역(시군구)별    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0         수원시  184402  202035  200113  195500  196453  189637  172210  177059
# 1         성남시  182500  171589  155354  162734  150240  152980  174390  157557
# 2        의정부시   65756   65206   61489   65548   63021   66820   65844   66965
# 3         안양시   99331   91534   96964   83335   81727   85267   96112   84779
# 4         부천시  136267  140599  124199  119427  117954  123425  125460  114426
# 5         광명시   87001   68937   52314   47076   46176   44735   41712   43201
# 6         평택시   67915   73419   72433   72028   68508   77256   75179   76783
# 7        동두천시   20437   17225   17907   15920   16052   16300   16074   13422
# 8         안산시  121052  119858  105760  101514   98715  103260   93537   78735
# 9         고양시  174090  173745  157485  171535  166111  176821  158904  139002
# 10        과천시   12035   11230   10328   10181    9925   10037   10957    8304
# ...

# %%
df_gygi[['2010', '2011', '2012', '2013', '2014', '2015', '2016','2017', '2018', '2019', '2020', '2021']] = \
df_gygi[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']].astype(float)

# %%
df_gygi = df_gygi.set_index("행정구역(시군구)별")

# %%
df_gygi_asc2021 = df_gygi.sort_values(by="2021", ascending=False)
df_gygi_asc2021
# Out:
#                 2010      2011      2012      2013      2014      2015  \
# 행정구역(시군구)별
# 수원시         184402.0  202035.0  200113.0  195500.0  196453.0  189637.0
# 용인시         178743.0  164017.0  157560.0  159125.0  159271.0  159061.0
# 화성시         101327.0   93509.0   82743.0   76374.0   81398.0  144301.0
# 고양시         174090.0  173745.0  157485.0  171535.0  166111.0  176821.0
# 성남시         182500.0  171589.0  155354.0  162734.0  150240.0  152980.0
# 평택시          67915.0   73419.0   72433.0   72028.0   68508.0   77256.0
# 남양주시        117456.0   90397.0  100136.0   95333.0   96997.0   95266.0
# 안산시         121052.0  119858.0  105760.0  101514.0   98715.0  103260.0
# 안양시          99331.0   91534.0   96964.0   83335.0   81727.0   85267.0
# 부천시         136267.0  140599.0  124199.0  119427.0  117954.0  123425.0
# 파주시          81782.0   82072.0   73676.0   64913.0   67889.0   69427.0
# 하남시          24274.0   24167.0   21424.0   19826.0   26015.0   45243.0
# ...

# %%
plt.figure(figsize = (16,10))
sns.heatmap(df_gygi_asc2021, annot=True, fmt = '.0f', cmap='rocket_r')
plt.title('2010~2021년 경기도 시별 전입인구 현황')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (30, 15)
plt.rcParams['lines.linewidth'] = 2
plt.rc("font", family = "Malgun Gothic", size=10)
df_df_gygi_asc2021_top10.T.plot()

plt.title("1")
plt.ylabel("1")

a = range(-1,32,1)
# plt.xticks([['2010', '2011', '2012', '2013', '2014', '2015', '2016','2017', '2018', '2019', '2020', '2021']])


plt.legend(loc="upper right")
plt.grid(True)

plt.show()

# %% [markdown]
# ### 주택보급률(아직 진행중)

# %%
df.columns = ['지역', '주택보급률', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2018', '2019', '2020']
df
# Out:
#      지역  주택보급률    2010    2011    2012    2013    2014    2015    2016  \
# 0    전국    가구수  17,656  17,928  18,209  18,500  18,800  19,111  19,368
# 1   NaN    주택수  17,739  18,082  18,414  18,742  19,161  19,559  19,877
# 2   NaN  주택보급률   100.5   100.9   101.1   101.3   101.9   102.3   102.6
# 3    서울    가구수   3,647   3,673   3,701   3,728   3,756   3,785   3,785
# 4   NaN    주택수   3,442   3,478   3,510   3,546   3,608   3,633   3,644
# 5   NaN  주택보급률    94.4    94.7    94.8    95.1    96.0    96.0    96.3
# 6    부산    가구수   1,254   1,269   1,285   1,301   1,318   1,336   1,344
# 7   NaN    주택수   1,251   1,270   1,295   1,323   1,352   1,370   1,376
# 8   NaN  주택보급률    99.7   100.1   100.8   101.7   102.6   102.6   102.3
# 9    대구    가구수     873     884     895     906     917     929     936
# 10  NaN    주택수     886     895     903     917     922     943     966
# 11  NaN  주택보급률   101.5   101.3   101.0   101.2   100.5   101.6   103.3
# ...

# %%
seoul_jutek = df[3:6]
gyeonggi_jutek = df[27:30]

# %%
seoul_jutek = seoul_jutek.fillna("서울")
seoul_jutek
# Out:
#    지역  주택보급률   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 3  서울    가구수  3,647  3,673  3,701  3,728  3,756  3,785  3,785  3,813  3,840
# 4  서울    주택수  3,442  3,478  3,510  3,546  3,608  3,633  3,644  3,672  3,682
# 5  서울  주택보급률   94.4   94.7   94.8   95.1   96.0   96.0   96.3   96.3   95.9
#
#     2019   2020
# 3  3,896  3,982
# 4  3,739  3,778
# 5   96.0   94.9

# %%
gyeonggi_jutek = gyeonggi_jutek.fillna("경기")
gyeonggi_jutek
# Out:
#     지역  주택보급률   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 27  경기    가구수  3,944  4,026  4,111  4,199  4,290  4,385  4,484  4,603  4,752
# 28  경기    주택수  3,839  3,931  4,041  4,119  4,219  4,329  4,444  4,580  4,798
# 29  경기  주택보급률   97.3   97.6   98.3   98.1   98.3   98.7   99.1   99.5  101.0
#
#      2019   2020
# 27  4,908  5,098
# 28  4,979  5,114
# 29  101.5  100.3

# %%
# 서울, 경기 주택보급률
jutek = pd.concat([seoul_jutek,gyeonggi_jutek], ignore_index=True)
jutek
# Out:
#    지역  주택보급률   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0  서울    가구수  3,647  3,673  3,701  3,728  3,756  3,785  3,785  3,813  3,840
# 1  서울    주택수  3,442  3,478  3,510  3,546  3,608  3,633  3,644  3,672  3,682
# 2  서울  주택보급률   94.4   94.7   94.8   95.1   96.0   96.0   96.3   96.3   95.9
# 3  경기    가구수  3,944  4,026  4,111  4,199  4,290  4,385  4,484  4,603  4,752
# 4  경기    주택수  3,839  3,931  4,041  4,119  4,219  4,329  4,444  4,580  4,798
# 5  경기  주택보급률   97.3   97.6   98.3   98.1   98.3   98.7   99.1   99.5  101.0
#
#     2019   2020
# 0  3,896  3,982
# 1  3,739  3,778
# 2   96.0   94.9
# 3  4,908  5,098
# 4  4,979  5,114
# 5  101.5  100.3

# %%
jutek = jutek.replace(',','',regex=True)
jutek
# Out:
#    지역  주택보급률  2010  2011  2012  2013  2014  2015  2016  2017   2018   2019  \
# 0  서울    가구수  3647  3673  3701  3728  3756  3785  3785  3813   3840   3896
# 1  서울    주택수  3442  3478  3510  3546  3608  3633  3644  3672   3682   3739
# 2  서울  주택보급률  94.4  94.7  94.8  95.1  96.0  96.0  96.3  96.3   95.9   96.0
# 3  경기    가구수  3944  4026  4111  4199  4290  4385  4484  4603   4752   4908
# 4  경기    주택수  3839  3931  4041  4119  4219  4329  4444  4580   4798   4979
# 5  경기  주택보급률  97.3  97.6  98.3  98.1  98.3  98.7  99.1  99.5  101.0  101.5
#
#     2020
# 0   3982
# 1   3778
# 2   94.9
# 3   5098
# 4   5114
# 5  100.3

# %%
jutek[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']] = \
    jutek[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']].astype(float)

# %%
jutekT = jutek.groupby("주택보급률").get_group("주택수").T
jutekT.drop[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\admin\STUDY\StudyPython_Advanced\MiniProject_1차\1_인구이동.ipynb Cell 11' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/STUDY/StudyPython_Advanced/MiniProject_1%EC%B0%A8/1_%EC%9D%B8%EA%B5%AC%EC%9D%B4%EB%8F%99.ipynb#ch0000011?line=0'>1</a> jutekT = jutek.groupby("주택보급률").get_group("주택수").T
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/STUDY/StudyPython_Advanced/MiniProject_1%EC%B0%A8/1_%EC%9D%B8%EA%B5%AC%EC%9D%B4%EB%8F%99.ipynb#ch0000011?line=1'>2</a> jutekT.drop[0]
#
# TypeError: 'method' object is not subscriptable

# %%
jutek = jutek.groupby(jutek['지역']=='서울')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\admin\STUDY\StudyPython_Advanced\MiniProject_1차\1_인구이동.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/STUDY/StudyPython_Advanced/MiniProject_1%EC%B0%A8/1_%EC%9D%B8%EA%B5%AC%EC%9D%B4%EB%8F%99.ipynb#ch0000017?line=0'>1</a> jutek = jutek.groupby(jutek['지역']=='서울')
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/STUDY/StudyPython_Advanced/MiniProject_1%EC%B0%A8/1_%EC%9D%B8%EA%B5%AC%EC%9D%B4%EB%8F%99.ipynb#ch0000017?line=1'>2</a> df.head()
#
# File c:\DEV\Langs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# ...
