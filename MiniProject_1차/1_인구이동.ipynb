# %%
import pandas as pd

# %%
file_path = "./data/1.전국_전출지_전입지_이동자수.csv"
df = pd.read_csv(file_path, encoding="EUC-KR")
df
# Out:
#         전출지별     전입지별      2010     2010.1      2011     2011.1      2012  \
# 0       전출지별     전입지별  이동자수 (명)  순이동자수 (명)  이동자수 (명)  순이동자수 (명)  이동자수 (명)
# 1         전국       전국   8226594          0   8127195          0   7506691
# 2         전국    서울특별시   1733015    -115023   1721748    -113058   1555281
# 3         전국    부산광역시    519334     -28466    508043     -24863    461042
# 4         전국    대구광역시    370817     -11840    370563     -12747    348642
# ..       ...      ...       ...        ...       ...        ...       ...
# 320  제주특별자치도     전라북도       672        114       561        -47       551
# 321  제주특별자치도     전라남도      1002        -27      1026         65       966
# 322  제주특별자치도     경상북도       738        -49       756        -33       699
# 323  제주특별자치도     경상남도      1324         10      1367         71      1227
# 324  제주특별자치도  제주특별자치도     55507          0     59846          0     54280
#
#         2012.1      2013     2013.1  ...      2017     2017.1      2018  \
# ...

# %%
df.drop([1,4])
# Out:
#     전출지별   전입지별      2010     2010.1      2011     2011.1      2012  \
# 0   전출지별   전입지별  이동자수 (명)  순이동자수 (명)  이동자수 (명)  순이동자수 (명)  이동자수 (명)
# 2  서울특별시    경기도    410735     124772    373771     101364    354135
# 3    경기도  서울특별시    285963    -124772    272407    -101364    254175
#
#       2012.1      2013     2013.1  ...      2017     2017.1      2018  \
# 0  순이동자수 (명)  이동자수 (명)  순이동자수 (명)  ...  이동자수 (명)  순이동자수 (명)  이동자수 (명)
# 2      99960    340801      94337  ...    342433     107985    368536
# 3     -99960    246464     -94337  ...    234448    -107985    233320
#
#       2018.1      2019     2019.1      2020     2020.1      2021     2021.1
# 0  순이동자수 (명)  이동자수 (명)  순이동자수 (명)  이동자수 (명)  순이동자수 (명)  이동자수 (명)  순이동자수 (명)
# 2     135216    334293      91954    375867     109492    362116     124910
# 3    -135216    242339     -91954    266375    -109492    237206    -124910
#
# [3 rows x 26 columns]
